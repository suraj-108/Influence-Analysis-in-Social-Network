# %%
import pandas as pd
  
# making data frame from csv file 
data = pd.read_csv("/content/drive/MyDrive/fb.csv")
  
# generating one row 
rows = data.sample(n=2000)
  
# checking if sample is 0.25 times data or not
  
if (0.25*(len(data))== len(rows)):
    print( "Cool")
    print(len(data), len(rows))
  
# display
rows
# Out:
#           0     1
# 74091  2829  3207
# 80789  3142  3426
# 82191  3281  3320
# 28442  1345  1841
# 67216  2484  2574
# ...     ...   ...
# 50540  2078  2154
# 46309  2021  2564
# 48243  2047  2325
# 48426  2052  2250
# 38903  1912  2201
#
# [2000 rows x 2 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import networkx as nx
import matplotlib.pyplot as plt
import csv
import random
import matplotlib.colors as mcolors
import random
import pandas as pd
import datetime
import io
import array,re,itertools
import numpy as np
import math

# %%
import csv
csv_file =input('/content/drive/MyDrive/fb.csv ')
txt_file =input('/content/drive/MyDrive/new.txt ')
with open(txt_file, "w") as my_output_file:
    with open(csv_file, "r") as my_input_file:
        [ my_output_file.write(" ".join(row)+'\n') for row in csv.reader(my_input_file)]
    my_output_file.close()
# Out:
# /content/drive/MyDrive/fb.csv /content/drive/MyDrive/fb.csv
# /content/drive/MyDrive/new.txt /content/drive/MyDrive/new.txt

# %% [markdown]
# # New Section

# %%
G_sampled = nx.read_edgelist(txt_file, nodetype=int, create_using=nx.DiGraph())
print (nx.info(G_sampled))
# Out:
# DiGraph with 4039 nodes and 88234 edges

# %%
result = []
F = open('/content/drive/My Drive/facebook_combined_Sample.txt', "w")
with open(txt_file) as fh:
    data = fh.readlines()
    for line in data:
        if line:
            words = line.split()
            result.append(words)
sample = random.sample(result, 20000)

for item in sample:
    F.write(item[0] + "\t" + item[1] + "\n")
print ("Sampled Dataset Information:")
G_sampled = nx.read_edgelist('/content/drive/My Drive/facebook_combined_Sample.txt', nodetype=int, create_using=nx.DiGraph())
print (nx.info(G_sampled))
# Out:
# Sampled Dataset Information:
# DiGraph with 3658 nodes and 17775 edges

# %%
initial_activated_nodes = random.randint(1, 100)
nodes = list(G_sampled.nodes)
print(initial_activated_nodes)
# Out:
# 21

# %%
activated_nodes=set()
activated_nodes.add(0)
activated_nodes.add(58)
activated_nodes.add(107)
activated_nodes.add(428)
activated_nodes.add(563)
activated_nodes.add(1085)
activated_nodes.add(1684)
activated_nodes.add(1912)
activated_nodes.add(2206)
activated_nodes.add(2233)
activated_nodes.add(2266)
activated_nodes.add(2464)
activated_nodes.add(3437)
print(activated_nodes)
# Out:
# {0, 2464, 2266, 107, 428, 3437, 563, 1684, 1912, 2233, 58, 1085, 2206}

# %%
remaining_activation = list(activated_nodes)

# %%
while(len(remaining_activation)):
    node = remaining_activation[0]
    remaining_activation.remove(node)
    nbrs = G_sampled.neighbors(node)
    for child in nbrs:
        if child not in activated_nodes:
            prob = random.uniform(0,1)
            if prob < 0.2:
                activated_nodes.add(child)
                remaining_activation.append(child)

# %%
colored = []
for nodes in G_sampled.nodes():
    if nodes in activated_nodes:
        colored.append('red')
    else:
        colored.append('white')
nx.draw(G_sampled, with_labels = False, node_size= 10 , node_color = colored)
